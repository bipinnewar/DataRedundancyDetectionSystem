# %%
import tkinter as tk
from tkinter import filedialog
import pandas as pd
import numpy as np
import time

def edit_distance(s1, s2):
    m = len(s1)
    n = len(s2)

    # initialize the matrix
    d = [[0] * (n + 1) for i in range(m + 1)]

    # fill the first row and first column
    for i in range(1, m + 1):
        d[i][0] = i
    for j in range(1, n + 1):
        d[0][j] = j

    # fill the rest of the matrix
    for j in range(1, n + 1):
        for i in range(1, m + 1):
            if s1[i - 1] == s2[j - 1]:
                d[i][j] = d[i - 1][j - 1]
            else:
                d[i][j] = min(d[i - 1][j], d[i][j - 1], d[i - 1][j - 1]) + 1

    # return the final value in the matrix
    return d[m][n]

def count_duplicates(records):
    count_dict = {}

    for row in records:
        record = tuple(row[1:])  # discard column 1

        if record in count_dict:
            count_dict[record]['count'] += 1
            count_dict[record]['ids'].append(row[0])  # add ID to list of IDs

        else:
            count_dict[record] = {'count': 1, 'ids': [row[0]]}

    duplicates = []
    total = 0
    for record, count_dict in count_dict.items():
        if count_dict['count'] > 1:
            duplicates.append(f"IDs: {', '.join(str(id) for id in count_dict['ids'])}, {record}: duplicate count: {count_dict['count']}")
            total = total + count_dict['count']

    lbl_total = tk.Label(window, text="Number of Duplicates: {}".format(total))
    lbl_total.pack()

    return duplicates

def show_column_selection_dialog(columns):
    def submit_selection():
        global selected_columns
        selected_columns = [column for column, var in column_vars.items() if var.get()]
        column_selection_window.destroy()

    column_selection_window = tk.Toplevel(window)
    column_selection_window.title("Select Columns")

    # Create a canvas and a scrollbar
    canvas = tk.Canvas(column_selection_window)
    scrollbar = tk.Scrollbar(column_selection_window, orient="vertical", command=canvas.yview)
    scrollable_frame = tk.Frame(canvas)

    scrollable_frame.bind(
        "<Configure>",
        lambda e: canvas.configure(scrollregion=canvas.bbox("all"))
    )

    canvas.create_window((0, 0), window=scrollable_frame, anchor="nw")
    canvas.pack(side="left", fill="both", expand=True)
    scrollbar.pack(side="right", fill="y")
    canvas.config(yscrollcommand=scrollbar.set)

    column_vars = {}

    for column in columns:
        var = tk.BooleanVar()
        chk = tk.Checkbutton(scrollable_frame, text=column, variable=var)
        chk.pack(anchor='w')
        column_vars[column] = var

    submit_button = tk.Button(column_selection_window, text="Submit", command=submit_selection)
    submit_button.pack(pady=10)

    column_selection_window.transient(window)
    column_selection_window.grab_set()
    window.wait_window(column_selection_window)

def upload_file():
    global selected_columns
    selected_columns = []  # Initialize this variable to store selected columns

    file = filedialog.askopenfilename(title="Select file", filetypes=[("CSV files", '.csv')])
    if file:
        lbl_my_file = tk.Label(window, text="File read!", font=("arial", 12, "bold"))
        lbl_my_file.pack()

        comparison = 0
        threshold = 5
        chunk_size = 50

        probable = []
        probable_dup = []

        df = pd.read_csv(file, infer_datetime_format=True, encoding='ISO-8859-1')

        file_name.set(file)

        # Show column selection dialog
        show_column_selection_dialog(df.columns)

        if not selected_columns:
            lbl_my_file.config(text="No columns selected. Please try again.")
            return

        # Clean up the data
        df.dropna(subset=selected_columns, inplace=True)

        # Create the `std_att` column dynamically based on selected columns
        df["std_att"] = df[selected_columns].astype(str).agg(''.join, axis=1)
        std_att = df["std_att"]

        # Continue with existing logic
        print("............Dataset..........")
        for index, row in df.iterrows():
            a = f"ID: {row['id']}, std_att: {row['std_att']}"
            print(a)

        mylist = tk.Text(window, height=15, width=150)
        mylist.pack(side=tk.TOP, padx=10, pady=10, expand=True)

        mylist1 = tk.Text(window, height=15, width=150)
        mylist1.pack(side=tk.BOTTOM, padx=10, pady=10, expand=True)

        unique_ids = []
        unique_std_att = []

        print("...........Edit Distance without sorting: ...........")
        for i in range(0, len(df), chunk_size):
            chunk = df.iloc[i:i + chunk_size]
            std_chunk = std_att.iloc[i:i + chunk_size]
            m = len(chunk)
            for j in range(m):
                for k in range(j + 1, m):
                    id_j = str(chunk.iloc[j]['id'])
                    id_k = str(chunk.iloc[k]['id'])
                    dist = edit_distance(std_chunk.iloc[j], std_chunk.iloc[k])
                    comparison += 1
                    if dist == 2 or dist == 1:
                        edit = (dist, f"Edit distance between ({id_j}){chunk.iloc[j]['std_att']} and ({id_k}){chunk.iloc[k]['std_att']} : {dist}")
                        probable_dup.append(edit)

                    if dist <= threshold:
                        pair = (dist, f"Edit distance between ({id_j}){chunk.iloc[j]['std_att']} and ({id_k}){chunk.iloc[k]['std_att']} : {dist}")
                        probable.append(pair)

                        if id_j not in unique_ids:
                            unique_ids.append(id_j)
                            unique_std_att.append((chunk.iloc[j]['id'], chunk.iloc[j]['std_att']))

                        if id_k not in unique_ids:
                            unique_ids.append(id_k)
                            unique_std_att.append((chunk.iloc[k]['id'], chunk.iloc[k]['std_att']))

        print("...........Edit Distance in Sorted order.............")
        probable = sorted(probable, key=lambda x: x[0])
        for pair in probable:
            print(pair[1])

        probable_dup = sorted(probable_dup, key=lambda x: x[0])
        mylist1.insert(tk.END, f"Probable Dupliates:\n")
        for edit in probable_dup:
            mylist1.insert(tk.END, f"{edit[1]}\n")
        mylist1.config(state='disabled')

        print("..........Dataset within the edit distance with unique id.............")
        print(unique_std_att)
        print("Length of unique attribute(edit distance): ", len(unique_std_att))

        duplicates = count_duplicates(unique_std_att)
        mylist.insert(tk.END, f"Exact Dupliates:\n")
        for i in range(len(duplicates)):
            mylist.insert(tk.END, f"{i + 1}: {duplicates[i]}\n")
        mylist.config(state='disabled')

        lbl_data = tk.Label(window, text="Number of data in dataset: {}".format(len(std_att)))
        lbl_data.pack()

        lbl_comparison = tk.Label(window, text="Number of Comparison: {}".format(comparison))
        lbl_comparison.pack()

# Initialize global variable
selected_columns = []

# Create the main window
window = tk.Tk()
window.geometry("1000x800")
window.title("Data Redundancy Detection System")
title_lbl = tk.Label(window, text="Upload .csv file", font=("arial", 30, "italic bold"), bd=7)
title_lbl.pack()

button = tk.Button(window, text="Upload File", relief=tk.RAISED, font=("arial", 15, "bold"), width=15, bg="light blue", command=upload_file)
button.pack()

file_name = tk.StringVar()
file_data = tk.StringVar()
my_file = tk.StringVar()

lbl_name = tk.Label(window, textvariable=file_name)
lbl_name.pack()

window.mainloop()
# Out:
# C:\Users\Bipin Shrestha\AppData\Local\Temp\ipykernel_9692\315331103.py:111: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_csv(file, infer_datetime_format=True, encoding='ISO-8859-1')
# ............Dataset..........
# ID: 121, std_att: Tek Bahadur Bista280
# ID: 122, std_att: Tek Bahadur Bista280
# ID: 125, std_att: Pratima Neupane190
# ID: 142, std_att: Bal Bd. Sarki330
# ID: 143, std_att: Dipak Singh Sarki440
# ID: 144, std_att: Shree Koli320
# ID: 146, std_att: Gaurab Bahadur Bist240
# ID: 147, std_att: Krisha Sharki20
# ID: 148, std_att: Narayan Prasad Timilsena330
# ID: 151, std_att: suman Chapagai280
# ID: 180, std_att: Bishnu Prasad Timilsena330
# ID: 181, std_att: Puran Karki300
# ID: 182, std_att: Parash Bista200
# ID: 183, std_att: Jivan Raj Upadhyay350
# ID: 184, std_att: Tapendra Upadhyay320
# ID: 185, std_att: Dhurba Bista180
# ID: 186, std_att: Parash Bista190
# ID: 187, std_att: Khem Bista190
# ID: 188, std_att: Laxman Bista180
# ID: 189, std_att: Hikmat Bista170
# ID: 190, std_att: Rabi Prasad Jaisi200
# ID: 191, std_att: Nar Bahadur Bista620
# ID: 192, std_att: Janak Bista540
# ID: 193, std_att: Topendra Kumar Shahi430
# ID: 194, std_att: Khem Raj Regmi330
# ID: 195, std_att: Sher Bahadur Shahi280
# ID: 196, std_att: Karishma Shahi250
# ...........Edit Distance without sorting: ...........
# ...........Edit Distance in Sorted order.............
# Edit distance between (121)Tek Bahadur Bista280 and (122)Tek Bahadur Bista280 : 0
# Edit distance between (182)Parash Bista200 and (186)Parash Bista190 : 2
# Edit distance between (121)Tek Bahadur Bista280 and (191)Nar Bahadur Bista620 : 5
# Edit distance between (122)Tek Bahadur Bista280 and (191)Nar Bahadur Bista620 : 5
# Edit distance between (147)Krisha Sharki20 and (196)Karishma Shahi250 : 5
# Edit distance between (188)Laxman Bista180 and (189)Hikmat Bista170 : 5
# ..........Dataset within the edit distance with unique id.............
# [(np.int64(121), 'Tek Bahadur Bista280'), (np.int64(122), 'Tek Bahadur Bista280'), (np.int64(191), 'Nar Bahadur Bista620'), (np.int64(147), 'Krisha Sharki20'), (np.int64(196), 'Karishma Shahi250'), (np.int64(182), 'Parash Bista200'), (np.int64(186), 'Parash Bista190'), (np.int64(188), 'Laxman Bista180'), (np.int64(189), 'Hikmat Bista170')]
# Length of unique attribute(edit distance):  9

# %%
import tkinter as tk
from tkinter import filedialog, Toplevel, Checkbutton, IntVar, Button, Label, Text, StringVar, Scrollbar, Frame
import pandas as pd
import numpy as np
import time

def edit_distance(s1, s2):
    m = len(s1)
    n = len(s2)

    # Initialize the matrix
    d = [[0] * (n + 1) for i in range(m + 1)]

    # Fill the first row and first column
    for i in range(1, m + 1):
        d[i][0] = i
    for j in range(1, n + 1):
        d[0][j] = j

    # Fill the rest of the matrix
    for j in range(1, n + 1):
        for i in range(1, m + 1):
            if s1[i - 1] == s2[j - 1]:
                d[i][j] = d[i - 1][j - 1]
            else:
                d[i][j] = min(d[i - 1][j], d[i][j - 1], d[i - 1][j - 1]) + 1

    # Return the final value in the matrix
    return d[m][n]

def count_duplicates(records, id_column_name):
    count_dict = {}

    for row in records:
        record = tuple(row[1:])  # Discard the first column (ID)

        if record in count_dict:
            count_dict[record]['count'] += 1
            count_dict[record]['ids'].append(row[0])  # Add ID to list of IDs
        else:
            count_dict[record] = {'count': 1, 'ids': [row[0]]}

    duplicates = []
    total = 0
    for record, details in count_dict.items():
        if details['count'] > 1:
            duplicates.append(f"IDs: {', '.join(str(id) for id in details['ids'])}, {record}: duplicate count: {details['count']}")
            total += details['count']

    lbl_total = Label(window, text=f"Number of Duplicates: {total}")
    lbl_total.pack()

    return duplicates

def upload_file():
    file = filedialog.askopenfilename(title="Select file", filetypes=[("CSV files", '*.csv')])
    if file:
        lbl_my_file = Label(window, text="File read!", font=("arial", 12, "bold"))
        lbl_my_file.pack()

        # Load the CSV file
        df = pd.read_csv(file, infer_datetime_format=True, encoding='ISO-8859-1')
        file_name.set(file)

        # Show column selection popup
        show_column_selection_popup(df)

def show_column_selection_popup(df):
    # Create a new window for column selection
    popup = Toplevel(window)
    popup.title("Select Columns for std_att")
    popup.geometry("400x600")

    # Create a frame for the checkboxes and scrollbars
    frame = Frame(popup)
    frame.pack(fill=tk.BOTH, expand=True)

    # Add a scrollbar to the frame
    scrollbar_y = Scrollbar(frame, orient=tk.VERTICAL)
    scrollbar_y.pack(side=tk.RIGHT, fill=tk.Y)
    
    canvas = tk.Canvas(frame, yscrollcommand=scrollbar_y.set)
    canvas.pack(side=tk.LEFT, fill=tk.BOTH, expand=True)

    scrollbar_y.config(command=canvas.yview)

    # Create a frame inside the canvas to hold the checkboxes
    checkbox_frame = Frame(canvas)
    canvas.create_window((0, 0), window=checkbox_frame, anchor=tk.NW)

    # Bind the frame to the canvas so that scrolling works
    def on_frame_configure(event):
        canvas.configure(scrollregion=canvas.bbox("all"))
    
    checkbox_frame.bind("<Configure>", on_frame_configure)

    # Create a list to keep track of selected columns
    selected_columns = []

    # Define a function to update the selected columns list
    def update_selection():
        selected_columns.clear()
        for var, col_name in column_vars:
            if var.get():
                selected_columns.append(col_name)
        popup.destroy()
        # Proceed with using selected columns
        create_std_att(df, selected_columns)

    # Create checkboxes for each column
    column_vars = []
    for col in df.columns:
        var = IntVar()
        chk = Checkbutton(checkbox_frame, text=col, variable=var)
        chk.pack(anchor=tk.W)
        column_vars.append((var, col))

    # Create a submit button
    submit_btn = Button(popup, text="Submit", command=update_selection)
    submit_btn.pack(pady=10)

def create_std_att(df, selected_columns):
    # Dynamically get the first column name
    id_column_name = df.columns[0]
    
    # Clean up the data
    df.dropna(subset=selected_columns, inplace=True)

    # Create std_att attribute based on selected columns
    df['std_att'] = df[selected_columns].astype(str).agg(''.join, axis=1)
    
    std = df[[id_column_name] + selected_columns].values
    unique_ids = []
    unique_std_att = []

    print("............Dataset..........")
    for index, row in df.iterrows():
        a = f"ID: {row[id_column_name]}, std_att: {row['std_att']}"
        print(a)

    mylist = Text(window, height=15, width=150)
    mylist.pack(side=tk.TOP, padx=10, pady=10, expand=True)

    mylist1 = Text(window, height=15, width=150)
    mylist1.pack(side=tk.BOTTOM, padx=10, pady=10, expand=True)

    comparison = 0
    threshold = 5
    chunk_size = 50

    probable = []
    probable_dup = []

    std_att = df['std_att']

    print("...........Edit Distance without sorting: ...........")
    for i in range(0, len(df), chunk_size):
        chunk = df.iloc[i:i+chunk_size]
        std_chunk = std_att.iloc[i:i+chunk_size]
        m = len(chunk)
        for j in range(m):
            for k in range(j + 1, m):
                id_j = str(chunk.iloc[j][id_column_name])
                id_k = str(chunk.iloc[k][id_column_name])
                dist = edit_distance(std_chunk.iloc[j], std_chunk.iloc[k])
                comparison += 1  # m * (m - 1) / 2
                if dist == 2 or dist == 1:
                    edit = (dist, f"Edit distance between ({id_j}){chunk.iloc[j]['std_att']} and ({id_k}){chunk.iloc[k]['std_att']} : {dist}")
                    probable_dup.append(edit)

                if dist <= threshold:
                    pair = (dist, f"Edit distance between ({id_j}){chunk.iloc[j]['std_att']} and ({id_k}){chunk.iloc[k]['std_att']} : {dist}")
                    probable.append(pair)

                    if id_j not in unique_ids:
                        unique_ids.append(id_j)
                        unique_std_att.append((chunk.iloc[j][id_column_name], chunk.iloc[j]['std_att']))

                    if id_k not in unique_ids:
                        unique_ids.append(id_k)
                        unique_std_att.append((chunk.iloc[k][id_column_name], chunk.iloc[k]['std_att']))

    print("...........Edit Distance in Sorted order.............")
    probable = sorted(probable, key=lambda x: x[0])  # sort by distance
    for pair in probable:
        print(pair[1])

    probable_dup = sorted(probable_dup, key=lambda x: x[0])  # sort by distance
    mylist1.insert(tk.END, f"Probable Dupliates:\n")
    z = 1
    for edit in probable_dup:
        mylist1.insert(tk.END, f"{z}: {edit[1]}\n")
        z = z + 1
    mylist1.config(state='disabled')

    print("..........Dataset within the edit distance with unique id.............")
    print(unique_std_att)
    print("Length of unique attribute(edit distance): ", len(unique_std_att))

    duplicates = count_duplicates(unique_std_att, id_column_name)
    mylist.insert(tk.END, f"Exact Dupliates:\n")
    for i in range(len(duplicates)):
        mylist.insert(tk.END, f"{i+1}: {duplicates[i]}\n")
    mylist.config(state='disabled')

    lbl_data = Label(window, text=f"Number of data in dataset: {len(std_att)}")
    lbl_data.pack()

    lbl_comparison = Label(window, text=f"Number of Comparison: {comparison}")
    lbl_comparison.pack()

start_time = time.time()

window = tk.Tk()
window.geometry("1000x800")
window.title("Data Redundancy Detection System")
title_lbl = Label(window, text="Upload .csv file", font=("arial", 30, "italic bold"), bd=7)
title_lbl.pack()
button = Button(window, text="Upload File", relief=tk.RAISED, font=("arial", 15, "bold"), width=15, bg="light blue", command=upload_file)
button.pack()

file_name = StringVar()
file_data = StringVar()
my_file = StringVar()

lbl_name = Label(window, textvariable=file_name)
lbl_name.pack()

window.mainloop()

end_time = time.time()
processing_time = end_time - start_time
print(f"\n \n \n Processing time: {processing_time} seconds")
# Out:
# C:\Users\Bipin Shrestha\AppData\Local\Temp\ipykernel_2104\3441200249.py:62: FutureWarning: The argument 'infer_datetime_format' is deprecated and will be removed in a future version. A strict version of it is now the default, see https://pandas.pydata.org/pdeps/0004-consistent-to-datetime-parsing.html. You can safely remove this argument.
#   df = pd.read_cs
# ID: 1479, std_att: 28MaleGloves
# ID: 1480, std_att: 48MaleCoat
# ID: 1481, std_att: 39MaleJewelry
# ID: 1482, std_att: 64MaleSkirt
# ID: 1483, std_att: 28MaleGloves
# ID: 1484, std_att: 39MaleJewelry
# ID: 1485, std_att: 49MaleShorts
# ID: 1486, std_att: 22MaleGloves
# ID: 1487, std_att: 25MaleSneakers
# ID: 1488, std_att: 40MaleSkirt
# ID: 1489, std_att: 23MaleHat
# ID: 1490, std_att: 24MaleJewelry
# ID: 1491, std_att: 66MaleSneakers
# ID: 1492, std_att: 27MaleShirt
# ID: 1493, std_att: 62MaleJacket
# ID: 1494, std_att: 70MaleBelt
# ID: 1495, std_att: 43MaleT-shirt
# ID: 1496, std_att: 45MaleJewelry
# ID: 1497, std_att: 63MaleT-shirt
# ID: 1498, std_att: 69MaleJacket
# ID: 1499, std_att: 59MaleSweater
# ID: 1500, std_att: 19MaleBoots
# ID: 1501, std_att: 63MaleJeans
# ID: 1502, std_att: 37MaleJeans
# ID: 1503, std_att: 37MalePants
# ID: 1504, std_att: 50MaleJacket
# ID: 1505, std_att: 60MaleJacket
# ID: 1506, std_att: 46MaleBelt
# ID: 1507, std_att: 35MaleShirt
# ID: 1508, std_att: 66MaleDress
# ID: 1509, std_att: 35MaleBlouse
# ID: 1510, std_att: 20MaleDress
# ID: 1511, std_att: 55MaleBlouse
# ID: 1512, std_att: 34MaleDress
# ID: 1513, std_att: 60MaleSneakers
# ID: 1514, std_att: 22MaleSocks
# ID: 1515, std_att: 26MaleShoes
# ...
# Edit distance between (3811)46FemaleSkirt and (3825)54FemaleShorts : 5
# Edit distance between (3811)46FemaleSkirt and (3845)30FemaleShorts : 5
# Edit distance between (3812)46FemaleBelt and (3815)45FemaleDress : 5
# Edit distance between (3812)46FemaleBelt and (3816)32FemaleHat : 5
# Edit distance between (3812)46FemaleBelt and (3817)29FemaleCoat : 5
# Edit distance between (3812)46FemaleBelt and (3820)36FemalePants : 5
# Edit distance between (3812)46FemaleBelt and (3823)70FemaleHat : 5
# Edit distance between (3812)46FemaleBelt and (3831)22FemaleHat : 5
# Edit distance between (3812)46FemaleBelt and (3833)64FemaleBoots : 5
# Edit distance between (3812)46FemaleBelt and (3839)47FemaleDress : 5
# Edit distance between (3812)46FemaleBelt and (3844)64FemaleHat : 5
# Edit distance between (3813)50FemaleSkirt and (3818)66FemaleScarf : 5
# Edit distance between (3813)50FemaleSkirt and (3823)70FemaleHat : 5
# Edit distance between (3813)50FemaleSkirt and (3826)49FemaleShorts : 5
# Edit distance between (3813)50FemaleSkirt and (3827)50FemaleJacket : 5
# Edit distance between (3814)61FemalePants and (3816)32FemaleHat : 5
# Edit distance between (3814)61FemalePants and (3823)70FemaleHat : 5
# Edit distance between (3814)61FemalePants and (3831)22FemaleHat : 5
# Edit distance between (3814)61FemalePants and (3840)66FemaleSandals : 5
# Edit distance between (3814)61FemalePants and (3841)30FemaleJeans : 5
# Edit distance between (3816)32FemaleHat and (3830)69FemalePants : 5
# Edit distance between (3816)32FemaleHat and (3837)62FemaleSkirt : 5
# Edit distance between (3816)32FemaleHat and (3841)30FemaleJeans : 5
# Edit distance between (3816)32FemaleHat and (3843)35FemaleJacket : 5
# Edit distance between (3817)29FemaleCoat and (3821)34FemaleBelt : 5
# Edit distance between (3817)29FemaleCoat and (3826)49FemaleShorts : 5
# Edit distance between (3817)29FemaleCoat and (3830)69FemalePants : 5
# Edit distance between (3817)29FemaleCoat and (3833)64FemaleBoots : 5
# Edit distance between (3818)66FemaleScarf and (3824)50FemaleShirt : 5
# Edit distance between (3818)66FemaleScarf and (3840)66FemaleSandals : 5
# Edit distance between (3818)66FemaleScarf and (3842)68FemaleJeans : 5
# Edit distance between (3818)66FemaleScarf and (3844)64FemaleHat : 5
# Edit distance between (3819)70FemaleSneakers and (3846)58FemaleSweater : 5
# Edit distance between (3820)36FemalePants and (3821)34FemaleBelt : 5
# Edit distance between (3820)36FemalePants and (3823)70FemaleHat : 5
# Edit distance between (3820)36FemalePants and (3831)22FemaleHat : 5
# Edit distance between (3820)36FemalePants and (3833)64FemaleBoots : 5
# Edit distance between (3820)36FemalePants and (3840)66FemaleSandals : 5
# Edit distance between (3820)36FemalePants and (3842)68FemaleJeans : 5
# Edit distance between (3820)36FemalePants and (3844)64FemaleHat : 5
# Edit distance between (3820)36FemalePants and (3845)30FemaleShorts : 5
# Edit distance between (3821)34FemaleBelt and (3823)70FemaleHat : 5
# Edit distance between (3821)34FemaleBelt and (3831)22FemaleHat : 5
# Edit distance between (3821)34FemaleBelt and (3841)30FemaleJeans : 5
# Edit distance between (3822)20FemaleSneakers and (3846)58FemaleSweater : 5
# Edit distance between (3823)70FemaleHat and (3824)50FemaleShirt : 5
# Edit distance between (3823)70FemaleHat and (3827)50FemaleJacket : 5
# Edit distance between (3823)70FemaleHat and (3830)69FemalePants : 5
# Edit distance between (3823)70FemaleHat and (3841)30FemaleJeans : 5
# Edit distance between (3824)50FemaleShirt and (3827)50FemaleJacket : 5
# Edit distance between (3825)54FemaleShorts and (3837)62FemaleSkirt : 5
# Edit distance between (3826)49FemaleShorts and (3830)69FemalePants : 5
# Edit distance between (3826)49FemaleShorts and (3833)64FemaleBoots : 5
# Edit distance between (3826)49FemaleShorts and (3837)62FemaleSkirt : 5
# Edit distance between (3829)42FemaleBlouse and (3833)64FemaleBoots : 5
# Edit distance between (3829)42FemaleBlouse and (3835)43FemaleHoodie : 5
# Edit distance between (3829)42FemaleBlouse and (3838)45FemaleHoodie : 5
# Edit distance between (3829)42FemaleBlouse and (3850)46FemaleHoodie : 5
# Edit distance between (3830)69FemalePants and (3831)22FemaleHat : 5
# Edit distance between (3830)69FemalePants and (3840)66FemaleSandals : 5
# Edit distance between (3830)69FemalePants and (3841)30FemaleJeans : 5
# Edit distance between (3831)22FemaleHat and (3837)62FemaleSkirt : 5
# Edit distance between (3833)64FemaleBoots and (3842)68FemaleJeans : 5
# Edit distance between (3833)64FemaleBoots and (3845)30FemaleShorts : 5
# Edit distance between (3833)64FemaleBoots and (3847)57FemaleBlouse : 5
# Edit distance between (3834)44FemaleJacket and (3844)64FemaleHat : 5
# Edit distance between (3837)62FemaleSkirt and (3844)64FemaleHat : 5
# Edit distance between (3837)62FemaleSkirt and (3845)30FemaleShorts : 5
# Edit distance between (3841)30FemaleJeans and (3845)30FemaleShorts : 5
# Edit distance between (3842)68FemaleJeans and (3844)64FemaleHat : 5
# Edit distance between (3852)50FemaleScarf and (3867)58FemaleHat : 5
# Edit distance between (3852)50FemaleScarf and (3877)60FemaleShoes : 5
# Edit distance between (3852)50FemaleScarf and (3879)60FemaleHat : 5
# Edit distance between (3852)50FemaleScarf and (3880)26FemaleSkirt : 5
# Edit distance between (3852)50FemaleScarf and (3881)42FemaleShirt : 5
# Edit distance between (3852)50FemaleScarf and (3891)35FemaleShirt : 5
# Edit distance between (3852)50FemaleScarf and (3895)66FemaleSkirt : 5
# Edit distance between (3853)65FemaleHat and (3860)65FemaleShorts : 5
# Edit distance between (3853)65FemaleHat and (3862)64FemaleJacket : 5
# Edit distance between (3853)65FemaleHat and (3891)35FemaleShirt : 5
# Edit distance between (3853)65FemaleHat and (3895)66FemaleSkirt : 5
# Edit distance between (3853)65FemaleHat and (3898)46FemaleBelt : 5
# Edit distance between (3855)57FemaleT-shirt and (3856)40FemaleShirt : 5
# Edit distance between (3855)57FemaleT-shirt and (3881)42FemaleShirt : 5
# Edit distance between (3855)57FemaleT-shirt and (3888)40FemaleShirt : 5
# Edit distance between (3855)57FemaleT-shirt and (3891)35FemaleShirt : 5
# Edit distance between (3856)40FemaleShirt and (3858)42FemaleHat : 5
# Edit distance between (3856)40FemaleShirt and (3865)55FemaleT-shirt : 5
# Edit distance between (3856)40FemaleShirt and (3872)55FemaleT-shirt : 5
# Edit distance between (3856)40FemaleShirt and (3879)60FemaleHat : 5
# Edit distance between (3856)40FemaleShirt and (3882)56FemaleScarf : 5
# Edit distance between (3856)40FemaleShirt and (3886)49FemaleSocks : 5
# Edit distance between (3856)40FemaleShirt and (3898)46FemaleBelt : 5
# Edit distance between (3857)39FemaleSandals and (3883)35FemalePants : 5
# Edit distance between (3858)42FemaleHat and (3864)40FemaleScarf : 5
# Edit distance between (3858)42FemaleHat and (3868)46FemaleJacket : 5
# Edit distance between (3858)42FemaleHat and (3873)41FemaleJacket : 5
# Edit distance between (3858)42FemaleHat and (3883)35FemalePants : 5
# Edit distance between (3858)42FemaleHat and (3888)40FemaleShirt : 5
# Edit distance between (3859)30FemaleT-shirt and (3863)56FemaleShirt : 5
# Edit distance between (3859)30FemaleT-shirt and (3881)42FemaleShirt : 5
# Edit distance between (3860)65FemaleShorts and (3880)26FemaleSkirt : 5
# Edit distance between (3860)65FemaleShorts and (3883)35FemalePants : 5
# Edit distance between (3860)65FemaleShorts and (3886)49FemaleSocks : 5
# Edit distance between (3862)64FemaleJacket and (3876)63FemaleHat : 5
# Edit distance between (3862)64FemaleJacket and (3879)60FemaleHat : 5
# Edit distance between (3862)64FemaleJacket and (3884)34FemaleHat : 5
# Edit distance between (3863)56FemaleShirt and (3864)40FemaleScarf : 5
# Edit distance between (3863)56FemaleShirt and (3867)58FemaleHat : 5
# Edit distance between (3863)56FemaleShirt and (3870)26FemaleCoat : 5
# Edit distance between (3863)56FemaleShirt and (3877)60FemaleShoes : 5
# Edit distance between (3863)56FemaleShirt and (3898)46FemaleBelt : 5
# Edit distance between (3863)56FemaleShirt and (3899)44FemaleShoes : 5
# Edit distance between (3864)40FemaleScarf and (3877)60FemaleShoes : 5
# Edit distance between (3864)40FemaleScarf and (3879)60FemaleHat : 5
# Edit distance between (3864)40FemaleScarf and (3880)26FemaleSkirt : 5
# Edit distance between (3864)40FemaleScarf and (3886)49FemaleSocks : 5
# Edit distance between (3864)40FemaleScarf and (3891)35FemaleShirt : 5
# Edit distance between (3864)40FemaleScarf and (3895)66FemaleSkirt : 5
# Edit distance between (3864)40FemaleScarf and (3899)44FemaleShoes : 5
# Edit distance between (3865)55FemaleT-shirt and (3881)42FemaleShirt : 5
# Edit distance between (3865)55FemaleT-shirt and (3888)40FemaleShirt : 5
# Edit distance between (3866)25FemaleShorts and (3870)26FemaleCoat : 5
# Edit distance between (3866)25FemaleShorts and (3883)35FemalePants : 5
# Edit distance between (3866)25FemaleShorts and (3886)49FemaleSocks : 5
# Edit distance between (3866)25FemaleShorts and (3895)66FemaleSkirt : 5
# Edit distance between (3867)58FemaleHat and (3882)56FemaleScarf : 5
# Edit distance between (3867)58FemaleHat and (3883)35FemalePants : 5
# Edit distance between (3867)58FemaleHat and (3898)46FemaleBelt : 5
# Edit distance between (3868)46FemaleJacket and (3886)49FemaleSocks : 5
# Edit distance between (3868)46FemaleJacket and (3898)46FemaleBelt : 5
# Edit distance between (3870)26FemaleCoat and (3882)56FemaleScarf : 5
# Edit distance between (3870)26FemaleCoat and (3895)66FemaleSkirt : 5
# Edit distance between (3872)55FemaleT-shirt and (3881)42FemaleShirt : 5
# Edit distance between (3872)55FemaleT-shirt and (3888)40FemaleShirt : 5
# Edit distance between (3873)41FemaleJacket and (3886)49FemaleSocks : 5
# Edit distance between (3873)41FemaleJacket and (3894)21FemaleHat : 5
# Edit distance between (3874)42FemaleSandals and (3900)52FemaleHandbag : 5
# Edit distance between (3875)70FemaleSweater and (3889)45FemaleSneakers : 5
# Edit distance between (3876)63FemaleHat and (3883)35FemalePants : 5
# Edit distance between (3876)63FemaleHat and (3895)66FemaleSkirt : 5
# Edit distance between (3876)63FemaleHat and (3898)46FemaleBelt : 5
# Edit distance between (3877)60FemaleShoes and (3879)60FemaleHat : 5
# Edit distance between (3877)60FemaleShoes and (3881)42FemaleShirt : 5
# Edit distance between (3877)60FemaleShoes and (3886)49FemaleSocks : 5
# Edit distance between (3877)60FemaleShoes and (3891)35FemaleShirt : 5
# Edit distance between (3877)60FemaleShoes and (3895)66FemaleSkirt : 5
# Edit distance between (3879)60FemaleHat and (3883)35FemalePants : 5
# Edit distance between (3879)60FemaleHat and (3888)40FemaleShirt : 5
# Edit distance between (3879)60FemaleHat and (3895)66FemaleSkirt : 5
# Edit distance between (3879)60FemaleHat and (3898)46FemaleBelt : 5
# Edit distance between (3880)26FemaleSkirt and (3894)21FemaleHat : 5
# Edit distance between (3880)26FemaleSkirt and (3898)46FemaleBelt : 5
# Edit distance between (3881)42FemaleShirt and (3882)56FemaleScarf : 5
# Edit distance between (3881)42FemaleShirt and (3886)49FemaleSocks : 5
# Edit distance between (3881)42FemaleShirt and (3898)46FemaleBelt : 5
# Edit distance between (3882)56FemaleScarf and (3888)40FemaleShirt : 5
# Edit distance between (3882)56FemaleScarf and (3891)35FemaleShirt : 5
# Edit distance between (3883)35FemalePants and (3891)35FemaleShirt : 5
# Edit distance between (3883)35FemalePants and (3892)36FemaleDress : 5
# Edit distance between (3883)35FemalePants and (3894)21FemaleHat : 5
# Edit distance between (3884)34FemaleHat and (3891)35FemaleShirt : 5
# Edit distance between (3884)34FemaleHat and (3898)46FemaleBelt : 5
# Edit distance between (3886)49FemaleSocks and (3888)40FemaleShirt : 5
# Edit distance between (3888)40FemaleShirt and (3898)46FemaleBelt : 5
# Edit distance between (3891)35FemaleShirt and (3899)44FemaleShoes : 5
# Edit distance between (3892)36FemaleDress and (3898)46FemaleBelt : 5
# Edit distance between (3894)21FemaleHat and (3898)46FemaleBelt : 5
# Edit distance between (3895)66FemaleSkirt and (3898)46FemaleBelt : 5
# ..........Dataset within the edit distance with unique id.............
# [(np.int64(1), '55MaleBlouse'), (np.int64(5), '45MaleBlouse'), (np.int64(11), '53MaleShoes'), (np.int64(36), '54MaleBlouse'), (np.int64(2), '19MaleSweater'), (np.int64(6), '46MaleSneakers'), (np.int64(19), '52MaleSweater'), (np.int64(3), '50MaleJeans'), (np.int64(18), '53MaleDress'), (np.int64(20), '66MalePants'), (np.int64(21), '21MalePants'), (np.int64(22), '31MalePants'), (np.int64(23), '56MalePants'), (np.int64(24), '31MalePants'), (np.int64(34), '54MalePants'), (np.int64(38), '35MaleJeans'), (np.int64(40), '70MalePants'), (np.int64(43), '20MaleCoat'), (np.int64(46), '50MaleSocks'), (np.int64(4), '21MaleSandals'), (np.int64(7), '63MaleShirt'), (np.int64(8), '27MaleShorts'), (np.int64(12), '30MaleShorts'), (np.int64(13), '61MaleCoat'), (np.int64(15), '64MaleCoat'), (np.int64(16), '64MaleSkirt'), (np.int64(28), '56MaleShorts'), (np.int64(35), '36MaleT-shirt'), (np.int64(37), '35MaleT-shirt'), (np.int64(42), '67MaleScarf'), (np.int64(44), '25MaleScarf'), (np.int64(47), '57MaleShirt'), (np.int64(49), '42MaleShirt'), (np.int64(9), '26MaleCoat'), (np.int64(45), '39MaleHat'), (np.int64(10), '57MaleHandbag'), (np.int64(29), '54MaleHandbag'), (np.int64(41), '69MaleHandbag'), (np.int64(32), '33MaleDress'), (np.int64(14), '65MaleDress'), (np.int64(30), '31MaleDress'), (np.int64(39), '29MaleDress'), (np.int64(25), '18MaleJacket'), (np.int64(33), '36MaleJacket'), (np.int64(26), '18MaleHoodie'), (np.int64(50), '68MaleHoodie'), (np.int64(27), '38MaleJewelry'), (np.int64(31), '57MaleJewelry'), (np.int64(48), '55MaleJewelry'), (np.int64(51), '49MaleBlouse'), (np.int64(59), '69MaleHoodie'), (np.int64(65), '65MaleBoots'), (np.int64(67), '31MaleBlouse'), (np.int64(75), '49MaleGloves'), (np.int64(52), '59MaleSkirt'), (np.int64(54), '29MaleSkirt'), (np.int64(62), '55MaleScarf'), (np.int64(76), '64MaleScarf'), (np.int64(77), '50MaleHat'), (np.int64(79), '50MaleSkirt'), (np.int64(85), '52MaleCoat'), (np.int64(88), '52MaleShoes'), (np.int64(92), '44MaleScarf'), (np.int64(95), '58MaleSkirt'), (np.int64(53), '42MaleT-shirt'), (np.int64(89), '33MaleT-shirt'), (np.int64(58), '21MaleCoat'), (np.int64(71), '22MaleBelt'), (np.int64(91), '25MaleHat'), (np.int64(98), '21MaleShoes'), (np.int64(55), '47MaleCoat'), (np.int64(60), '63MaleBelt'), (np.int64(68), '45MaleCoat'), (np.int64(70), '48MaleBelt'), (np.int64(74), '48MalePants'), (np.int64(82), '67MaleShoes'), (np.int64(90), '47MaleJacket'), (np.int64(56), '40MaleJacket'), (np.int64(80), '38MaleJacket'), (np.int64(93), '61MaleJacket'), (np.int64(57), '41MaleBackpack'), (np.int64(66), '65MaleBackpack'), (np.int64(99), '20MaleJeans'), (np.int64(87), '24MaleHoodie'), (np.int64(100), '26MaleHoodie'), (np.int64(61), '50MaleSweater'), (np.int64(63), '30MaleSneakers'), (np.int64(94), '37MaleSweater'), (np.int64(96), '37MaleSneakers'), (np.int64(64), '33MaleSunglasses'), (np.int64(86), '53MaleSunglasses'), (np.int64(83), '19MalePants'), (np.int64(97), '32MaleGloves'), (np.int64(73), '18MaleDress'), (np.int64(78), '22MaleDress'), (np.int64(72), '36MaleDress'), (np.int64(84), '36MaleDress'), (np.int64(81), '19MaleSandals'), (np.int64(101), '62MaleSunglasses'), (np.int64(105), '55MaleSunglasses'), (np.int64(102), '27MaleCoat'), (np.int64(104), '54MaleBoots'), (np.int64(112), '26MaleBelt'), (np.int64(114), '44MaleHat'), (np.int64(115), '70MaleCoat'), (np.int64(120), '38MaleCoat'), (np.int64(121), '64MaleHat'), (np.int64(129), '20MaleScarf'), (np.int64(132), '28MaleSkirt'), (np.int64(135), '43MaleHat'), (np.int64(140), '49MaleCoat'), (np.int64(144), '30MaleCoat'), (np.int64(103), '51MaleSocks'), (np.int64(109), '70MaleSocks'), (np.int64(116), '53MaleSkirt'), (np.int64(117), '55MaleShoes'), (np.int64(122), '19MaleShorts'), (np.int64(126), '49MaleShorts'), (np.int64(127), '43MaleShorts'), (np.int64(142), '56MaleGloves'), (np.int64(145), '19MaleShoes'), (np.int64(147), '52MaleSkirt'), (np.int64(148), '63MaleShoes'), (np.int64(130), '24MaleDress'), (np.int64(137), '39MaleBlouse'), (np.int64(150), '38MalePants'), (np.int64 ...
# Length of unique attribute(edit distance):  3809
#
#
#
#  Processing time: 94.20638537406921 seconds
